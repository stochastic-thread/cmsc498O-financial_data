# %%
pylab.rcParams['figure.figsize'] = (15.0, 20.0)
data1 = np.genfromtxt('eza_12.csv', delimiter=',', skip_header=10, skip_footer=10, names=['x1', 'y1'])
data2 = np.genfromtxt('eza_24.csv', delimiter=',', skip_header=10, skip_footer=10, names=['x2', 'y2'])
data3 = np.genfromtxt('eza_diff.csv', delimiter=',', skip_header=10, skip_footer=10, names=['x3', 'y3'])
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(data2['x2'], log(log(data2['y2'])), color='blue', label='the data')
ax1.scatter(data1['x1'], log(log(data1['y1'])), color='yellow', label='the data')
ax1.scatter(data3['x3'], log(log(data3['y3'])), color='green', label='the data')

# %%
log(8)
# Out:
# 2.0794415416798357

# %%
data1 = np.genfromtxt('eurodollar_12.csv', delimiter=',', skip_header=10, skip_footer=10, names=['x1', 'y1'])
data2 = np.genfromtxt('eurodollar_24.csv', delimiter=',', skip_header=10, skip_footer=10, names=['x2', 'y2'])
data3 = np.genfromtxt('eurodollar_diff.csv', delimiter=',', skip_header=10, skip_footer=10, names=['x3', 'y3'])
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(data2['x2'], log(log(data2['y2'])), color='blue', label='the data')
ax1.scatter(data1['x1'], log(log(data1['y1'])), color='yellow', label='the data')
ax1.scatter(data3['x3'], log(log(data3['y3'])), color='green', label='the data')
# Out:
# -c:6: RuntimeWarning: divide by zero encountered in log
# -c:6: RuntimeWarning: invalid value encountered in log

# %%
pylab.rcParams['figure.figsize'] = (20.0, 20.0)
data1 = np.genfromtxt('dollaryen_24.csv', delimiter=',', skip_header=10, skip_footer=10, names=['x1', 'y1'])
data2 = np.genfromtxt('dollaryen_12.csv', delimiter=',', skip_header=10, skip_footer=10, names=['x2', 'y2'])
data3 = np.genfromtxt('dollaryen_diff.csv', delimiter=',', skip_header=10, skip_footer=10, names=['x3', 'y3'])
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(data2['x2'], data2['y2'], color='blue', label='the data')
ax1.scatter(data1['x1'], data1['y1'], color='yellow', label='the data')
ax1.scatter(data3['x3'], data3['y3'], color='green', label='the data')

# %%
data = np.genfromtxt('poundyen_diff.csv', delimiter=',', skip_header=10, skip_footer=10, names=['x', 'y'])
data3 = np.genfromtxt('dollaryen_diff.csv', delimiter=',', skip_header=10, skip_footer=10, names=['x3', 'y3'])
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(data['x'], data['y'], color='blue', label='the data')
ax1.scatter(data3['x3'], data3['y3'], color='green', label='the data')

# %%
pylab.rcParams['figure.figsize'] = (20.0, 20.0)
data = np.genfromtxt('eurodollar_diff.csv', delimiter=',', skip_header=10, skip_footer=10, names=['x', 'y'])
data3 = np.genfromtxt('dollaryen_diff.csv', delimiter=',', skip_header=10, skip_footer=10, names=['x3', 'y3'])
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(data['x'], data['y'], color='blue', label='the data')
ax1.scatter(data3['x3'], data3['y3'], color='green', label='the data')

# %%
pylab.rcParams['figure.figsize'] = (15.0, 20.0)
data = np.genfromtxt('eurodollar_diff.csv', delimiter=',', skip_header=10, skip_footer=10, names=['x', 'y'])
data3 = np.genfromtxt('eza_diff.csv', delimiter=',', skip_header=10, skip_footer=10, names=['x3', 'y3'])
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(data['x'], data['y'], color='blue', label='the data')
ax1.scatter(data3['x3'], data3['y3'], color='green', label='the data')
